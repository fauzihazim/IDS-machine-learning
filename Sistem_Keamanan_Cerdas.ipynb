# %% [markdown]
# # Import Library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as matplot
import numpy as np

import re
import sklearn

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

df_train = pd.read_csv('Train_data.csv')
df_test = pd.read_csv('test_data.csv')
df_test = df_test.drop('Unnamed: 0',axis=1)

# %% [markdown]
# # Exploring the data

# %%
df_train.head()
# Out:
#    duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0          icmp       20     2        491          0     0
# 1         0           udp       45     2        146          0     0
# 2         0          icmp       50     4          0          0     0
# 3         0          icmp       25     2        232       8153     0
# 4         0          icmp       25     2        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  xAttack
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00      dos
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
df_test.head()
# Out:
#    duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0          icmp       25     4          0          0     0
# 1         0          icmp       25     2        312       1856     0
# 2         0          icmp       25     2        245       2058     0
# 3         0          icmp       25     2        298       1267     0
# 4         0          icmp       20     2        740          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                 255
# 1               0       0    0  ...                 254
# 2               0       0    0  ...                 255
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                  19
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    1.00                    0.00
# 1                    1.00                    0.00
# 2                    1.00                    0.00
# 3                    1.00                    0.00
# 4                    0.18                    0.03
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.00                         0.00
# 1                         1.00                         0.06
# 2                         0.01                         0.05
# 3                         0.00                         0.00
# 4                         0.18                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.65                      0.65                  0.32
# 1                  0.00                      0.00                  0.00
# 2                  0.01                      0.00                  0.00
# 3                  0.00                      0.00                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  xAttack
# 0                      0.32      dos
# 1                      0.00   normal
# 2                      0.00   normal
# 3                      0.00   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %% [markdown]
# # Save training dataset and test dataset to each df and split X and Y (xAttack, analysis features).

# %%
X_train = df_train.drop('xAttack', axis=1)
Y_train = df_train.loc[:,['xAttack']]
X_test = df_test.drop('xAttack', axis=1)
Y_test = df_test.loc[:,['xAttack']]

# %%
print(Y_train.apply(lambda col: col.unique()))
# Out:
#   xAttack
# 0  normal
# 1     dos
# 2     r2l
# 3   probe
# 4     u2r

# %% [markdown]
# # Preprocessing and one hot encoding, X is onehotencoder, Y is LabelBinarizer

# %%
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder

# %%
le = preprocessing.LabelEncoder()
enc = OneHotEncoder()
lb = preprocessing.LabelBinarizer()

# %% [markdown]
# # X OneHotEncoding

# %%
X_train['protocol_type'] = le.fit_transform(X_train['protocol_type'])
# enc.fit_transform(X_train['protocol_type'])

X_test['protocol_type'] = le.fit_transform(X_test['protocol_type'])
# enc.fit_transform(X_test['protocol_type'])

X_train.head()
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              0       20     2        491          0     0
# 1         0              2       45     2        146          0     0
# 2         0              0       50     4          0          0     0
# 3         0              0       25     2        232       8153     0
# 4         0              0       25     2        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# 0               0       0    0  ...             150                  25
# 1               0       0    0  ...             255                   1
# 2               0       0    0  ...             255                  26
# 3               0       0    0  ...              30                 255
# 4               0       0    0  ...             255                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate
# 0                      0.00
# 1                      0.00
# 2                      0.00
# 3                      0.01
# 4                      0.00
#
# [5 rows x 41 columns]

# %% [markdown]
# # Y LabelBinarizer

# %%
Y_train['xAttack'] = le.fit_transform(Y_train['xAttack'])
lb.fit_transform(Y_train['xAttack'])

Y_test['xAttack'] = le.fit_transform(Y_test['xAttack'])
lb.fit_transform(Y_test['xAttack'])

Y_train.describe()
# Out:
#              xAttack
# count  125973.000000
# mean        0.744985
# std         0.653748
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         4.000000

# %% [markdown]
# # 1. Standard deviation

# %%
#except continuous feature
con_list = ['protocol_type', 'service', 'flag', 'land', 'logged_in', 'su_attempted', 'is_host_login', 'is_guest_login']
con_train = X_train.drop(con_list, axis=1)

#drop n smallest std features
stdtrain = con_train.std(axis=0)
std_X_train = stdtrain.to_frame()
std_X_train.nsmallest(10, columns=0).head(10)
# Out:
#                                     0
# num_outbound_cmds            0.000000
# urgent                       0.014366
# num_shells                   0.022181
# root_shell                   0.036603
# num_failed_logins            0.045239
# num_access_files             0.099370
# dst_host_srv_diff_host_rate  0.112564
# diff_srv_rate                0.180314
# dst_host_diff_srv_rate       0.188922
# wrong_fragment               0.253530

# %%
# num_outbound_cmds is removed from the first because the standard deviation is zero.
X_train = X_train.drop(['num_outbound_cmds'], axis=1)
X_test = X_test.drop(['num_outbound_cmds'], axis=1)

df_train = pd.concat([X_train, Y_train], axis=1)
df_train.head()

X_train.head()
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              0       20     2        491          0     0
# 1         0              2       45     2        146          0     0
# 2         0              0       50     4          0          0     0
# 3         0              0       25     2        232       8153     0
# 4         0              0       25     2        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# 0               0       0    0  ...             150                  25
# 1               0       0    0  ...             255                   1
# 2               0       0    0  ...             255                  26
# 3               0       0    0  ...              30                 255
# 4               0       0    0  ...             255                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate
# 0                      0.00
# 1                      0.00
# 2                      0.00
# 3                      0.01
# 4                      0.00
#
# [5 rows x 40 columns]

# %%
# Std picks the 10 low and stores the features in drop -> X_train_stdrop. (Will be used after ensemble feature selection)
stdrop_list = ['urgent', 'num_shells', 'root_shell',
        'num_failed_logins', 'num_access_files', 'dst_host_srv_diff_host_rate',
        'diff_srv_rate', 'dst_host_diff_srv_rate', 'wrong_fragment']

X_test_stdrop = X_test.drop(stdrop_list, axis=1)

X_train_stdrop = X_train.drop(stdrop_list, axis=1)

df_train_stdrop = pd.concat([X_train_stdrop, Y_train], axis=1)

df_train_stdrop.head()
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  hot  \
# 0         0              0       20     2        491          0     0    0
# 1         0              2       45     2        146          0     0    0
# 2         0              0       50     4          0          0     0    0
# 3         0              0       25     2        232       8153     0    0
# 4         0              0       25     2        199        420     0    0
#
#    logged_in  num_compromised  ...  srv_diff_host_rate  dst_host_count  \
# 0          0                0  ...                0.00             150
# 1          0                0  ...                0.00             255
# 2          0                0  ...                0.00             255
# 3          1                0  ...                0.00              30
# 4          1                0  ...                0.09             255
#
#    dst_host_srv_count  dst_host_same_srv_rate  dst_host_same_src_port_rate  \
# 0                  25                    0.17                         0.17
# 1                   1                    0.00                         0.88
# 2                  26                    0.10                         0.00
# 3                 255                    1.00                         0.03
# 4                 255                    1.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  xAttack
# 0                      0.00        1
# 1                      0.00        1
# 2                      0.00        0
# 3                      0.01        1
# 4                      0.00        1
#
# [5 rows x 32 columns]

# %%
# Baseline - Learn about performance with linear regression
# Linear regression

from sklearn import linear_model

# %%
LR = linear_model.LinearRegression()

# %%
LR.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
lr_score = LR.score(X_test, Y_test)
print('Linear regression processing ,,,')
print('Linear regression Score: %.2f %%' % lr_score)
# Out:
# Linear regression processing ,,,
# Linear regression Score: 0.33 %

# %% [markdown]
# # 2. Ensemble feature selection¶

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.tree import DecisionTreeClassifier

# %%
AB = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=100, learning_rate=1.0)
RF = RandomForestClassifier(n_estimators=10, criterion='entropy', max_features='auto', bootstrap=True)
ET = ExtraTreesClassifier(n_estimators=10, criterion='gini', max_features='auto', bootstrap=False)
GB = GradientBoostingClassifier(loss='deviance', learning_rate=0.1, n_estimators=200, max_features='auto')

# %%
y_train = Y_train['xAttack'].ravel()
x_train = X_train.values
x_test = X_test.values

# %%
# Check the feature importances to see how accurate the basic features are.
AB.fit(X_train, Y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=100)

# %%
AB_feature = AB.feature_importances_
AB_feature

ab_score = AB.score(X_test, Y_test)

print('AdaBoostClassifier processing ,,,')
print('AdaBoostClassifier Score: %.3f %%' % ab_score)
# Out:
# AdaBoostClassifier processing ,,,
# AdaBoostClassifier Score: 0.756 %

# %%
RF.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_features='auto',
#                        n_estimators=10)

# %%
RF_feature = RF.feature_importances_
RF_feature

rf_score = RF.score(X_test, Y_test)

print('RandomForestClassifier processing ,,,')
print('RandomForestClassifier Score: %.3f %%' % rf_score)
# Out:
# RandomForestClassifier processing ,,,
# RandomForestClassifier Score: 0.760 %

# %%
ET.fit(X_train, Y_train)
# Out:
# ExtraTreesClassifier(max_features='auto', n_estimators=10)

# %%
ET_feature = ET.feature_importances_
ET_feature

et_score = ET.score(X_test, Y_test)

print('ExtraTreesClassifier processing ,,,')
print('ExtraTreeClassifier: %.3f %%' % et_score)
# Out:
# ExtraTreesClassifier processing ,,,
# ExtraTreeClassifier: 0.758 %

# %%
GB.fit(X_train, Y_train)
# Out:
# GradientBoostingClassifier(loss='deviance', max_features='auto',
#                            n_estimators=200)

# %%
GB_feature = GB.feature_importances_
GB_feature

gb_score = GB.score(X_test, Y_test)

print('GradientBoostingClassifier processing ,,,')
print('GradientBoostingClassifier Score: %.3f %%' % gb_score)
# Out:
# GradientBoostingClassifier processing ,,,
# GradientBoostingClassifier Score: 0.767 %

# %%
cols = X_train.columns.values

feature_df = pd.DataFrame({'features': cols,
                           'AdaBoost' : AB_feature,
                           'RandomForest' : RF_feature,
                           'ExtraTree' : ET_feature,
                           'GradientBoost' : GB_feature
                          })
feature_df.head(8)
# Out:
#          features  AdaBoost  RandomForest  ExtraTree  GradientBoost
# 0        duration  0.000066      0.003369   0.002159       0.001016
# 1   protocol_type  0.460444      0.023381   0.035579       0.011389
# 2         service  0.520246      0.026031   0.020243       0.007783
# 3            flag  0.000049      0.037910   0.026120       0.001151
# 4       src_bytes  0.006691      0.270832   0.017935       0.361443
# 5       dst_bytes  0.001449      0.038388   0.005821       0.062839
# 6            land  0.000005      0.000003   0.000071       0.000036
# 7  wrong_fragment  0.000105      0.005286   0.015381       0.013345

# %%
# Graphs showing the influence of features

from matplotlib.ticker import MaxNLocator
from collections import namedtuple

graph = feature_df.plot.bar(figsize = (18, 10), title = 'Feature distribution', grid=True, legend=True, fontsize = 15,
                            xticks=feature_df.index)
graph.set_xticklabels(feature_df.features, rotation = 80)
# Out:
# [Text(0, 0, 'duration'),
#  Text(1, 0, 'protocol_type'),
#  Text(2, 0, 'service'),
#  Text(3, 0, 'flag'),
#  Text(4, 0, 'src_bytes'),
#  Text(5, 0, 'dst_bytes'),
#  Text(6, 0, 'land'),
#  Text(7, 0, 'wrong_fragment'),
#  Text(8, 0, 'urgent'),
#  Text(9, 0, 'hot'),
#  Text(10, 0, 'num_failed_logins'),
#  Text(11, 0, 'logged_in'),
#  Text(12, 0, 'num_compromised'),
#  Text(13, 0, 'root_shell'),
#  Text(14, 0, 'su_attempted'),
#  Text(15, 0, 'num_root'),
#  Text(16, 0, 'num_file_creations'),
#  Text(17, 0, 'num_shells'),
#  Text(18, 0, 'num_access_files'),
#  Text(19, 0, 'is_host_login'),
#  Text(20, 0, 'is_guest_login'),
#  Text(21, 0, 'count'),
#  Text(22, 0, 'srv_count'),
#  Text(23, 0, 'serror_rate'),
#  Text(24, 0, 'srv_serror_rate'),
#  Text(25, 0, 'rerror_rate'),
#  Text(26, 0, 'srv_rerror_rate'),
#  Text(27, 0, 'same_srv_rate'),
#  Text(28, 0, 'diff_srv_rate'),
#  Text(29, 0, 'srv_diff_host_rate'),
#  Text(30, 0, 'dst_host_count'),
#  Text(31, 0, 'dst_host_srv_count'),
#  Text(32, 0, 'dst_host_same_srv_rate'),
#  Text(33, 0, 'dst_host_diff_srv_rate'),
#  Text(34, 0, 'dst_host_same_src_port_rate'),
#  Text(35, 0, 'dst_host_srv_diff_host_rate'),
#  Text(36, 0, 'dst_host_serror_rate'),
#  Text(37, 0, 'dst_host_srv_serror_rate'),
#  Text(38, 0, 'dst_host_rerror_rate'),
#  Text(39, 0, 'dst_host_srv_rerror_rate')]

# %%
# Extract twelve features from each Ensemble model¶

a_f = feature_df.nlargest(12, 'AdaBoost')
e_f = feature_df.nlargest(12, 'ExtraTree')
g_f = feature_df.nlargest(12, 'GradientBoost')
r_f = feature_df.nlargest(12, 'RandomForest')

# %%
# Delete Duplicates
result = pd.concat([a_f, e_f, g_f, r_f])
result = result.drop_duplicates() # delete duplicate feature
result
# Out:
#                        features      AdaBoost  RandomForest  ExtraTree  \
# 2                       service  5.202457e-01      0.026031   0.020243
# 1                 protocol_type  4.604436e-01      0.023381   0.035579
# 4                     src_bytes  6.690639e-03      0.270832   0.017935
# 27                same_srv_rate  4.401338e-03      0.062006   0.152612
# 21                        count  2.364132e-03      0.065373   0.023888
# 33       dst_host_diff_srv_rate  1.810904e-03      0.057495   0.033053
# 5                     dst_bytes  1.448815e-03      0.038388   0.005821
# 34  dst_host_same_src_port_rate  7.836242e-04      0.024647   0.055437
# 36         dst_host_serror_rate  3.461957e-04      0.044706   0.051694
# 31           dst_host_srv_count  3.123605e-04      0.014820   0.009968
# 32       dst_host_same_srv_rate  1.660470e-04      0.073194   0.092569
# 12              num_compromised  1.588366e-04      0.001721   0.007707
# 24              srv_serror_rate  3.925481e-07      0.000955   0.060761
# 37     dst_host_srv_serror_rate  2.033929e-05      0.003402   0.057542
# 23                  serror_rate  1.801273e-05      0.058941   0.052852
# 30               dst_host_count  6.745279e-05      0.012843   0.048159
# 11                    logged_in  5.939930e-05      0.018390   0.047796
# 39     dst_host_srv_rerror_rate  1.608321e-05      0.011199   0.039372
# 25                  rerror_rate  1.455010e-05      0.004476   0.034299
# 35  dst_host_srv_diff_host_rate  5.649410e-05      0.010360   0.014668
# 28                diff_srv_rate  1.151261e-04      0.045919   0.015732
# 7                wrong_fragment  1.051117e-04      0.005286   0.015381
# 22                    srv_count  8.128624e-05      0.046248   0.023249
# 3                          flag  4.856911e-05      0.037910   0.026120
#
#     GradientBoost
# 2        0.007783
# 1        0.011389
# 4        0.361443
# 27       0.194893
# 21       0.054400
# 33       0.051018
# 5        0.062839
# 34       0.008551
# 36       0.078089
# 31       0.017992
# 32       0.003451
# 12       0.006713
# 24       0.000349
# 37       0.000316
# 23       0.012296
# 30       0.007838
# 11       0.002512
# 39       0.000064
# 25       0.000029
# 35       0.049492
# 28       0.035083
# 7        0.013345
# 22       0.008265
# 3        0.001151

# %%
selected_features = result['features'].values.tolist()
selected_features
# Out:
# ['service',
#  'protocol_type',
#  'src_bytes',
#  'same_srv_rate',
#  'count',
#  'dst_host_diff_srv_rate',
#  'dst_bytes',
#  'dst_host_same_src_port_rate',
#  'dst_host_serror_rate',
#  'dst_host_srv_count',
#  'dst_host_same_srv_rate',
#  'num_compromised',
#  'srv_serror_rate',
#  'dst_host_srv_serror_rate',
#  'serror_rate',
#  'dst_host_count',
#  'logged_in',
#  'dst_host_srv_rerror_rate',
#  'rerror_rate',
#  'dst_host_srv_diff_host_rate',
#  'diff_srv_rate',
#  'wrong_fragment',
#  'srv_count',
#  'flag']

# %%
# Below are the results of training with the exception of the features with small standard deviations.¶
AB.fit(X_train_stdrop, Y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=100)

# %%
ab2_score = AB.score(X_test_stdrop, Y_test)

print('AdaBoostClassifier_stdrop processing ,,,')
print('AdaBoostClasifier Score: %.3f %%' % ab2_score)
# Out:
# AdaBoostClassifier_stdrop processing ,,,
# AdaBoostClasifier Score: 0.736 %

# %%
RF.fit(X_train_stdrop, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_features='auto',
#                        n_estimators=10)

# %%
rf2_score = RF.score(X_test_stdrop, Y_test)

print('RandomForestClassifier_stdrop processing ,,,')
print('RandomForestClassifier Score: %.3f %%' % rf2_score)
# Out:
# RandomForestClassifier_stdrop processing ,,,
# RandomForestClassifier Score: 0.763 %

# %%
ET.fit(X_train_stdrop, Y_train)
# Out:
# ExtraTreesClassifier(max_features='auto', n_estimators=10)

# %%
et2_score = ET.score(X_test_stdrop, Y_test)

print('ExtraTreesClassifier_stdrop processing ,,,')
print('ExtraTreesClassifier Score: %.3f %%' % et2_score)
# Out:
# ExtraTreesClassifier_stdrop processing ,,,
# ExtraTreesClassifier Score: 0.754 %

# %%
GB.fit(X_train_stdrop, Y_train)
# Out:
# GradientBoostingClassifier(loss='deviance', max_features='auto',
#                            n_estimators=200)

# %%
gb2_score = GB.score(X_test_stdrop, Y_test)

print('GradientBoostingClassifier_stdrop processing ,,,')
print('GradientBoostingClassifier Score: %.2f %%' % gb2_score)
# Out:
# GradientBoostingClassifier_stdrop processing ,,,
# GradientBoostingClassifier Score: 0.75 %

# %%
X_train_ens = X_train[selected_features]
X_train_ens.head()

X_test_ens = X_test[selected_features]
X_test_ens.head()
# Out:
#    service  protocol_type  src_bytes  same_srv_rate  count  \
# 0       25              0          0            1.0    110
# 1       25              0        312            1.0      1
# 2       25              0        245            1.0      5
# 3       25              0        298            1.0      4
# 4       20              0        740            1.0      1
#
#    dst_host_diff_srv_rate  dst_bytes  dst_host_same_src_port_rate  \
# 0                    0.00          0                         0.00
# 1                    0.00       1856                         1.00
# 2                    0.00       2058                         0.01
# 3                    0.00       1267                         0.00
# 4                    0.03          0                         0.18
#
#    dst_host_serror_rate  dst_host_srv_count  ...  serror_rate  dst_host_count  \
# 0                  0.65                 255  ...          1.0             255
# 1                  0.00                 254  ...          0.0               1
# 2                  0.01                 255  ...          0.0             114
# 3                  0.00                 255  ...          0.0             255
# 4                  0.00                  19  ...          0.0             104
#
#    logged_in  dst_host_srv_rerror_rate  rerror_rate  \
# 0          0                      0.32          0.0
# 1          1                      0.00          0.0
# 2          1                      0.00          0.0
# 3          1                      0.00          0.0
# 4          0                      0.00          0.0
#
#    dst_host_srv_diff_host_rate  diff_srv_rate  wrong_fragment  srv_count  flag
# 0                         0.00            0.0               0        110     4
# 1                         0.06            0.0               0          9     2
# 2                         0.05            0.0               0          5     2
# 3                         0.00            0.0               0         18     2
# 4                         0.00            0.0               0          1     2
#
# [5 rows x 24 columns]

# %% [markdown]
# # 3. Correlation

# %%
sample = X_train_ens[:10000]

colormap = plt.cm.viridis
plt.figure(figsize=(20, 20))
sns.heatmap(sample.astype(float).corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# The above graph analysis shows that the dependency is high in the following features¶

# %%
selected2 = ['flag', 'dst_host_serror_rate', 'serror_rate']
X_train_cordrop = X_train_ens.drop(selected2, axis=1)
X_train_cordrop.describe()

X_test_cordrop = X_test_ens.drop(selected2, axis=1)
X_test_cordrop.describe()
# Out:
#             service  protocol_type     src_bytes  same_srv_rate         count  \
# count  10000.000000   10000.000000  1.000000e+04   10000.000000  10000.000000
# mean      35.451700       0.278600  6.845032e+03       0.739925     80.152400
# std       15.824769       0.657134  8.675409e+04       0.413711    129.028094
# min        1.000000       0.000000  0.000000e+00       0.000000      1.000000
# 25%       25.000000       0.000000  0.000000e+00       0.200000      1.000000
# 50%       25.000000       0.000000  5.400000e+01       1.000000      8.000000
# 75%       50.000000       0.000000  2.850000e+02       1.000000    126.000000
# max       70.000000       2.000000  6.291668e+06       1.000000    511.000000
#
#        dst_host_diff_srv_rate     dst_bytes  dst_host_same_src_port_rate  \
# count            10000.000000  1.000000e+04                 10000.000000
# mean                 0.089412  1.996999e+03                     0.133167
# std                  0.218190  2.006975e+04                     0.307154
# min                  0.000000  0.000000e+00                     0.000000
# 25%                  0.000000  0.000000e+00                     0.000000
# 50%                  0.020000  4.400000e+01                     0.000000
# 75%                  0.060000  5.990000e+02                     0.030000
# max                  1.000000  1.285078e+06                     1.000000
#
#        dst_host_srv_count  dst_host_same_srv_rate  ...  srv_serror_rate  \
# count        10000.000000            10000.000000  ...     10000.000000
# mean           139.645700                0.605769  ...         0.101696
# std            111.548555                0.436278  ...         0.295464
# min              0.000000                0.000000  ...         0.000000
# 25%             15.000000                0.070000  ...         0.000000
# 50%            159.500000                0.910000  ...         0.000000
# 75%            255.000000                1.000000  ...         0.000000
# max            255.000000                1.000000  ...         1.000000
#
#        dst_host_srv_serror_rate  dst_host_count     logged_in  \
# count              10000.000000    10000.000000  10000.000000
# mean                   0.097781      194.522200      0.436600
# std                    0.279651       93.746065      0.495989
# min                    0.000000        0.000000      0.000000
# 25%                    0.000000      125.000000      0.000000
# 50%                    0.000000      255.000000      0.000000
# 75%                    0.000000      255.000000      1.000000
# max                    1.000000      255.000000      1.000000
#
#        dst_host_srv_rerror_rate   rerror_rate  dst_host_srv_diff_host_rate  \
# count              10000.000000  10000.000000                 10000.000000
# mean                   0.230181      0.241316                     0.020102
# std                    0.403294      0.418059                     0.089353
# min                    0.000000      0.000000                     0.000000
# 25%                    0.000000      0.000000                     0.000000
# 50%                    0.000000      0.000000                     0.000000
# 75%                    0.220000      0.330000                     0.010000
# max                    1.000000      1.000000                     1.000000
#
#        diff_srv_rate  wrong_fragment     srv_count
# count   10000.000000    10000.000000  10000.000000
# mean        0.089752        0.009000     31.730900
# std         0.252240        0.146701     90.353536
# min         0.000000        0.000000      1.000000
# 25%         0.000000        0.000000      1.000000
# 50%         0.000000        0.000000      6.000000
# 75%         0.060000        0.000000     16.000000
# max         1.000000        3.000000    511.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# # 2) Modeling

# %%
AB.fit(X_train_cordrop, Y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=100)

# %%
ab_finalscore = AB.score(X_test_cordrop, Y_test)

print('AdaBoostClassifier_final processing ,,,')
print('AdaBoostClassifier_final Score: %.3f %%' % ab_finalscore)
# Out:
# AdaBoostClassifier_final processing ,,,
# AdaBoostClassifier_final Score: 0.746 %

# %%
RF.fit(X_train_cordrop, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_features='auto',
#                        n_estimators=10)

# %%
rf_finalscore = RF.score(X_test_cordrop, Y_test)

print('RandomForestClassifier_final processing ,,,')
print('RandomForestClassifier_final Score: %.3f %%' % rf_finalscore)
# Out:
# RandomForestClassifier_final processing ,,,
# RandomForestClassifier_final Score: 0.751 %

# %%
ET.fit(X_train_cordrop, Y_train)
# Out:
# ExtraTreesClassifier(max_features='auto', n_estimators=10)

# %%
et_finalscore = ET.score(X_test_cordrop, Y_test)

print('ExtraTreesClassifier_final processing ,,,')
print('ExtraTreesClassifier_final Score: %.3f %%' % et_finalscore)
# Out:
# ExtraTreesClassifier_final processing ,,,
# ExtraTreesClassifier_final Score: 0.770 %

# %%
GB.fit(X_train_cordrop, Y_train)
# Out:
# GradientBoostingClassifier(loss='deviance', max_features='auto',
#                            n_estimators=200)

# %%
gb_finalscore = GB.score(X_test_cordrop, Y_test)

print('GradientBoostClassifier_final processing ,,,')
print('GradientBoostClassifier_final Score: %.3f %%' % gb_finalscore)
# Out:
# GradientBoostClassifier_final processing ,,,
# GradientBoostClassifier_final Score: 0.763 %

# %%
LR.fit(X_train_cordrop, Y_train)
# Out:
# LinearRegression()

# %%
lr_finalscore = LR.score(X_test_cordrop, Y_test)

print('LinearRegression_final processing ,,,')
print('LinearRegression_final Score: %.3f %%' % lr_finalscore)
# Out:
# LinearRegression_final processing ,,,
# LinearRegression_final Score: 0.290 %

# %%
from sklearn.neural_network import MLPClassifier

# %%
MLP = MLPClassifier(hidden_layer_sizes=(1000, 300, 300), solver='adam', shuffle=False, tol = 0.0001)

# %%
MLP.fit(X_train_cordrop, Y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(1000, 300, 300), shuffle=False)

# %%
mlp_finalscore = MLP.score(X_test_cordrop, Y_test)

print('MLP_final processing ,,,')
print('MLP_final Score: %.3f %%' % mlp_finalscore)
# Out:
# MLP_final processing ,,,
# MLP_final Score: 0.384 %

# %% [markdown]
# # 3) Result

# %%
first_model = {'Model': ['Linear Regression', 'Adaboost', 'RandomForest', 'ExtraTrees', 'GradientBoost'],
               'accuracy' : [lr_score, ab_score, rf_score, et_score, gb_score]}

result_df = pd.DataFrame(data = first_model)
result_df
# Out:
#                Model  accuracy
# 0  Linear Regression  0.334265
# 1           Adaboost  0.756200
# 2       RandomForest  0.760200
# 3         ExtraTrees  0.758200
# 4      GradientBoost  0.766800

# %%
r1 = result_df.plot(x='Model', y='accuracy', kind='bar', figsize=(8, 8), grid=True, title='FIRST MODEL ACCURACY', colormap=plt.cm.viridis,
               sort_columns=True)
r1.set_xticklabels(result_df.Model, rotation = 45)
# Out:
# [Text(0, 0, 'Linear Regression'),
#  Text(1, 0, 'Adaboost'),
#  Text(2, 0, 'RandomForest'),
#  Text(3, 0, 'ExtraTrees'),
#  Text(4, 0, 'GradientBoost')]

# %%
second_model = {'Model': ['Adaboost', 'RandomForest', 'ExtraTrees', 'GradientBoost'],
               'accuracy' : [ab2_score, rf2_score, et2_score, gb2_score]}

result_df = pd.DataFrame(data = second_model)
result_df
# Out:
#            Model  accuracy
# 0       Adaboost    0.7359
# 1   RandomForest    0.7628
# 2     ExtraTrees    0.7543
# 3  GradientBoost    0.7507

# %%
r2 = result_df.plot(x='Model', y='accuracy', kind='bar', figsize=(8, 8), grid=True, title='SECOND MODEL ACCURACY', colormap=plt.cm.viridis,
               sort_columns=True)
r2.set_xticklabels(result_df.Model, rotation = 45)
# Out:
# [Text(0, 0, 'Adaboost'),
#  Text(1, 0, 'RandomForest'),
#  Text(2, 0, 'ExtraTrees'),
#  Text(3, 0, 'GradientBoost')]

# %%
# Final model
final_model = {'Model': ['Linear Regression', 'Adaboost', 'RandomForest', 'ExtraTrees', 'GradientBoost', 'MLP'],
               'accuracy' : [lr_finalscore, ab_finalscore, rf_finalscore, et_finalscore, gb_finalscore, mlp_finalscore]}

result_df = pd.DataFrame(data = final_model)
result_df
# Out:
#                Model  accuracy
# 0  Linear Regression  0.289695
# 1           Adaboost  0.745900
# 2       RandomForest  0.751100
# 3         ExtraTrees  0.770500
# 4      GradientBoost  0.763300
# 5                MLP  0.384000

# %%
r3 = result_df.plot(x='Model', y='accuracy', kind='bar', figsize=(8, 8), grid=True, title='FINAL MODEL ACCURACY', colormap=plt.cm.viridis,
               sort_columns=True)
r3.set_xticklabels(result_df.Model, rotation = 45)
# Out:
# [Text(0, 0, 'Linear Regression'),
#  Text(1, 0, 'Adaboost'),
#  Text(2, 0, 'RandomForest'),
#  Text(3, 0, 'ExtraTrees'),
#  Text(4, 0, 'GradientBoost'),
#  Text(5, 0, 'MLP')]

# %% [markdown]
# # FASTEST AND ACCURATE MODEL - ExtraTrees of the final model (76.4%)
# # STRONGEST AND THE MOST ACCURATE MODEL - GradientBoost of the final model (77.1%)

# %% [markdown]
# Gradient boost has a 77 percent chance, but the speed is significantly faster with ExtraTress.
